# %%
import pandas as pd
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.isna().sum()
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=1)
x_train
# Out:
#      5.1  3.5  1.4  0.2
# 127  6.4  2.8  5.6  2.1
# 98   5.7  2.8  4.1  1.3
# 42   5.0  3.5  1.6  0.6
# 136  6.4  3.1  5.5  1.8
# 28   4.7  3.2  1.6  0.2
# ..   ...  ...  ...  ...
# 133  6.1  2.6  5.6  1.4
# 137  6.0  3.0  4.8  1.8
# 72   6.1  2.8  4.7  1.2
# 140  6.9  3.1  5.1  2.3
# 37   4.4  3.0  1.3  0.2
#
# [119 rows x 4 columns]

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from collections import Counter
print(Counter(y_pred))
# Out:
# Counter({'Iris-versicolor': 14, 'Iris-setosa': 10, 'Iris-virginica': 6})

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
x1=m.fit_transform(x)
df=pd.DataFrame(x1)
df
# Out:
#             0         1         2         3
# 0    0.166667  0.416667  0.067797  0.041667
# 1    0.111111  0.500000  0.050847  0.041667
# 2    0.083333  0.458333  0.084746  0.041667
# 3    0.194444  0.666667  0.067797  0.041667
# 4    0.305556  0.791667  0.118644  0.125000
# ..        ...       ...       ...       ...
# 144  0.666667  0.416667  0.711864  0.916667
# 145  0.555556  0.208333  0.677966  0.750000
# 146  0.611111  0.416667  0.711864  0.791667
# 147  0.527778  0.583333  0.745763  0.916667
# 148  0.444444  0.416667  0.694915  0.708333
#
# [149 rows x 4 columns]

# %%
x2=df.iloc[:,:-1]

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(x2,y,random_state=1,train_size=0.8)
y1_train
# Out:
# 127     Iris-virginica
# 98     Iris-versicolor
# 42         Iris-setosa
# 136     Iris-virginica
# 28         Iris-setosa
#             ...
# 133     Iris-virginica
# 137     Iris-virginica
# 72     Iris-versicolor
# 140     Iris-virginica
# 37         Iris-setosa
# Name: Iris-setosa, Length: 119, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x1_train,y1_train)
y_pred=lr.predict(x1_test)
print(accuracy_score(y1_test,y_pred)*100)
# Out:
# 80.0

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
t=s.fit_transform(x)
t
# Out:
# array([[-1.1483555 , -0.11805969, -1.35396443, -1.32506301],
#        [-1.3905423 ,  0.34485856, -1.41098555, -1.32506301],
#        [-1.51163569,  0.11339944, -1.29694332, -1.32506301],
#        [-1.02726211,  1.27069504, -1.35396443, -1.32506301],
#        [-0.54288852,  1.9650724 , -1.18290109, -1.0614657 ],
#        [-1.51163569,  0.8077768 , -1.35396443, -1.19326436],
#        [-1.02726211,  0.8077768 , -1.29694332, -1.32506301],
#        [-1.75382249, -0.34951881, -1.35396443, -1.32506301],
#        [-1.1483555 ,  0.11339944, -1.29694332, -1.45686167],
#        [-0.54288852,  1.50215416, -1.29694332, -1.32506301],
#        [-1.2694489 ,  0.8077768 , -1.23992221, -1.32506301],
#        [-1.2694489 , -0.11805969, -1.35396443, -1.45686167],
#        [-1.87491588, -0.11805969, -1.52502777, -1.45686167],
#        [-0.05851493,  2.19653152, -1.46800666, -1.32506301],
#        [-0.17960833,  3.122368  , -1.29694332, -1.0614657 ],
# ...

# %%
df=pd.DataFrame(t)
df
# Out:
#             0         1         2         3
# 0   -1.148356 -0.118060 -1.353964 -1.325063
# 1   -1.390542  0.344859 -1.410986 -1.325063
# 2   -1.511636  0.113399 -1.296943 -1.325063
# 3   -1.027262  1.270695 -1.353964 -1.325063
# 4   -0.542889  1.965072 -1.182901 -1.061466
# ..        ...       ...       ...       ...
# 144  1.031326 -0.118060  0.812838  1.442709
# 145  0.546952 -1.275355  0.698796  0.915514
# 146  0.789139 -0.118060  0.812838  1.047313
# 147  0.425859  0.807777  0.926880  1.442709
# 148  0.062578 -0.118060  0.755817  0.783716
#
# [149 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(df,y,train_size=0.8,random_state=1)
y_test
# Out:
# 145     Iris-virginica
# 89     Iris-versicolor
# 54     Iris-versicolor
# 77     Iris-versicolor
# 84     Iris-versicolor
# 105     Iris-virginica
# 91     Iris-versicolor
# 53     Iris-versicolor
# 44         Iris-setosa
# 59     Iris-versicolor
# 5          Iris-setosa
# 16         Iris-setosa
# 93     Iris-versicolor
# 14         Iris-setosa
# 58     Iris-versicolor
# 33         Iris-setosa
# 73     Iris-versicolor
# 29         Iris-setosa
# 66     Iris-versicolor
# 35         Iris-setosa
# 119     Iris-virginica
# 144     Iris-virginica
# 31         Iris-setosa
# 130     Iris-virginica
# 111     Iris-virginica
# 19         Iris-setosa
# 51     Iris-versicolor
# 48         Iris-setosa
# 90     Iris-versicolor
# 102     Iris-virginica
# Name: Iris-setosa, dtype: object

# %%
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 96.66666666666667

# %% [markdown]
# ### lab 2

# %%
df=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQV0ktrVSaCtsI_VeguDX64mEsDFE2YUc3Ypvz5-uOJp5zIfwGt-wlbX-QfnKWQRvHAj9mVAiOPGdQv/pub?gid=1780346880&single=true&output=csv")
df
# Out:
#        Unnamed: 0          id             date   price  bedrooms  bathrooms  \
# 0               0  7129300520  20141013T000000  221900       3.0       1.00
# 1               1  6414100192  20141209T000000  538000       3.0       2.25
# 2               2  5631500400  20150225T000000  180000       2.0       1.00
# 3               3  2487200875  20141209T000000  604000       4.0       3.00
# 4               4  1954400510  20150218T000000  510000       3.0       2.00
# ...           ...         ...              ...     ...       ...        ...
# 21608       21608   263000018  20140521T000000  360000       3.0       2.50
# 21609       21609  6600060120  20150223T000000  400000       4.0       2.50
# 21610       21610  1523300141  20140623T000000  402101       2.0       0.75
# 21611       21611   291310100  20150116T000000  400000       3.0       2.50
# 21612       21612  1523300157  20141015T000000  325000       2.0       0.75
#
# ...

# %%
df["date"]
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
df=df.fillna(df.mean())
# Out:
# <ipython-input-36-6f8c6f28e805>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.mean())

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
x=df["sqft_living"]
y=df["price"]
x
# Out:
# 0        1180
# 1        2570
# 2         770
# 3        1960
# 4        1680
#          ...
# 21608    1530
# 21609    2310
# 21610    1020
# 21611    1600
# 21612    1020
# Name: sqft_living, Length: 21613, dtype: int64

# %%
import numpy as np
slope=np.sum(x-np.mean(x)*(y-np.mean(y)))/(np.sum(x-np.mean(x))**2)
intercept=np.mean(y)-slope*np.mean(x)
print(slope,intercept)
# Out:
# 1.973192489276712e+24 -4.1040425380562576e+27

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x,slope*x+intercept,color="red")
plt.show()

# %%
import numpy as np
x=np.array(x).reshape(-1,1)
x
# Out:
# array([[1180],
#        [2570],
#        [ 770],
#        ...,
#        [1020],
#        [1600],
#        [1020]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([ 733776.4919685 ,  416143.19106732,  618771.33129738, ...,
#         449001.80840193, 1412854.58355033,  380546.3556215 ])

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# -30186.361061054864
# [273.82181112]

# %%
pred_slope=lr.coef_
pred_inter=lr.intercept_

# %%
x,y
# Out:
# (array([[1180],
#         [2570],
#         [ 770],
#         ...,
#         [1020],
#         [1600],
#         [1020]]),
#  0        221900
#  1        538000
#  2        180000
#  3        604000
#  4        510000
#            ...
#  21608    360000
#  21609    400000
#  21610    402101
#  21611    400000
#  21612    325000
#  Name: price, Length: 21613, dtype: int64)

# %%
r_squared=lr.score(x_test,y_test)
r_squared
# Out:
# 0.5033019006466926

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred,squared=False))
# Out:
# 85730574276.16481
# 292797.8385783693

# %%
x=df[['bedrooms','bathrooms','sqft_living']]
y=df["price"]
x
# Out:
#        bedrooms  bathrooms  sqft_living
# 0           3.0       1.00         1180
# 1           3.0       2.25         2570
# 2           2.0       1.00          770
# 3           4.0       3.00         1960
# 4           3.0       2.00         1680
# ...         ...        ...          ...
# 21608       3.0       2.50         1530
# 21609       4.0       2.50         2310
# 21610       2.0       0.75         1020
# 21611       3.0       2.50         1600
# 21612       2.0       0.75         1020
#
# [21613 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1,train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(lr.coef_,lr.intercept_)
# Out:
# [-54756.51491562   5333.61306643    302.88516793] 82684.4546714861

# %%
r_squared=lr.score(x_test,y_test)
r_squared
# Out:
# 0.5191271859819306

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred,squared=False))
# Out:
# 82999114659.86964
# 288095.66928343376

# %%
x_train
# Out:
#        bedrooms  bathrooms  sqft_living
# 7291        3.0       1.75         2190
# 14835       3.0       2.50         2370
# 15880       2.0       1.00         1230
# 8812        4.0       2.25         2510
# 17220       3.0       1.00         1160
# ...         ...        ...          ...
# 10955       3.0       2.50         1920
# 17289       4.0       4.50         3420
# 5192        3.0       1.75         1970
# 12172       3.0       2.25         1980
# 235         5.0       4.00         3760
#
# [17290 rows x 3 columns]

# %%
from sklearn.linear_model import Ridge
r=Ridge()
r.fit(x_train,y_train)
y_pred=r.predict(x_test)
y_pred
# Out:
# array([ 723376.19454424,  424116.75973401,  699002.84425077, ...,
#         456464.34563389, 1422441.62275   ,  382076.31805131])

# %%
print(r.score(x_test,y_test))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred,squared=False))
print(r.coef_)
print(r.intercept_)
# Out:
# 0.5191264595868305
# 82999240036.36932
# 288095.8868786039
# [-54750.83505232   5331.21799963    302.88332833]
# 82674.19921399897

# %%
from sklearn.linear_model import Lasso
l=Lasso()
l.fit(x_train,y_train)
y_pred=l.predict(x_test)
print(l.score(x_test,y_test))
print(l.coef_)
print(l.intercept_)
# Out:
# 0.5191270578102107
# [-54755.62806337   5332.53448242    302.88532905]
# 82683.411610184

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred,squared=False))
# Out:
# 82999136782.43295
# 288095.7076779051

# %% [markdown]
# ### LAB-3

# %%
import pandas as pd
df=pd.read_csv("https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Class",data=df)
plt.show()

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
y.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
k=KNeighborsClassifier(n_neighbors=5)
k.fit(x_train,y_train)
k1=k.score(x_test,y_test)
k1
# Out:
# 0.9984902215512096

# %%
# Balance the dataset using Random Over sampling
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(x_train, y_train)

#class wise disctributions in train data split after random over sampling
print("class wise disctributions in train data split after random over sampling")
print(y_resampled.value_counts())


# Implement KNN model for classifying data balanced using Random Over sampling
knn_ros = KNeighborsClassifier(n_neighbors=5)
knn_ros.fit(X_resampled, y_resampled)
ros_score = knn_ros.score(x_test, y_test)
print('KNN accuracy on Random Over sampled data:', ros_score)
# Out:
# class wise disctributions in train data split after random over sampling
# 0    227440
# 1    227440
# Name: Class, dtype: int64
# KNN accuracy on Random Over sampled data: 0.9970857764825674

# %%
from imblearn.under_sampling import RandomUnderSampler
rus=RandomUnderSampler(random_state=42)
x1_re,y1_re=rus.fit_resample(x_train,y_train)
print(y1_re.value_counts())
k=KNeighborsClassifier(n_neighbors=5)
k.fit(x1_re,y1_re)
print(k.score(x_test,y_test))
# Out:
# 0    405
# 1    405
# Name: Class, dtype: int64
# 0.6270320564586918

# %%
from imblearn.over_sampling import SMOTE
s=SMOTE(random_state=42)
x2_re,y2_re=s.fit_resample(x_train,y_train)
print(y2_re.value_counts())
# Out:
# 0    227440
# 1    227440
# Name: Class, dtype: int64

# %% [markdown]
# ### lab-7

# %%
import pandas as pd
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1,train_size=0.8)

# %%
from sklearn.naive_bayes import GaussianNB
g=GaussianNB()
g.fit(x_train,y_train)
y_pred=g.predict(x_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica'], dtype='<U15')

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.92      0.92      0.92        13
#  Iris-virginica       0.86      0.86      0.86         7
#
#        accuracy                           0.93        30
#       macro avg       0.93      0.93      0.93        30
#    weighted avg       0.93      0.93      0.93        30

# %%
from sklearn.metrics import confusion_matrix
n=confusion_matrix(y_test,y_pred)

# %%
import seaborn as sns
sns.heatmap(n, annot=True, cmap='Blues', fmt='g')
# Out:
# <Axes: >

# %% [markdown]
# ### PCA

# %%
data = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTsTahZpKiB1lFKXlRTTyS5HvZu8t3Q6pZtUSqsYTzhVxRZ5H3aqIlYR4mpBngQKDKv4FWRmwGKuaoq/pub?output=csv")
data
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1,train_size=0.8)

# %%
from sklearn.naive_bayes import GaussianNB
g=GaussianNB()
g.fit(x_train,y_train)
y_pred=g.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.92      0.92      0.92        13
#  Iris-virginica       0.86      0.86      0.86         7
#
#        accuracy                           0.93        30
#       macro avg       0.93      0.93      0.93        30
#    weighted avg       0.93      0.93      0.93        30

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_train_pca=pca.fit_transform(x_train)
x_test_pca=pca.transform(x_test)
x_train_pca.shape
# Out:
# (119, 2)

# %%
g=GaussianNB()
g.fit(x_train_pca,y_train)
y_pred=g.predict(x_test_pca)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9333333333333333

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda=LDA(n_components=2)
x_train_lda=lda.fit_transform(x_train,y_train)
x_test_lda=lda.transform(x_test)
x_test_lda.shape
# Out:
# (30, 2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_lda,y_train)
print(knn.score(x_test_lda,y_test))
# Out:
# 1.0

# %% [markdown]
# ### KMEANS

# %%
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
df.head
# Out:
# <bound method NDFrame.head of      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]>

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x
# Out:
#      5.1  3.5  1.4  0.2
# 0    4.9  3.0  1.4  0.2
# 1    4.7  3.2  1.3  0.2
# 2    4.6  3.1  1.5  0.2
# 3    5.0  3.6  1.4  0.2
# 4    5.4  3.9  1.7  0.4
# ..   ...  ...  ...  ...
# 144  6.7  3.0  5.2  2.3
# 145  6.3  2.5  5.0  1.9
# 146  6.5  3.0  5.2  2.0
# 147  6.2  3.4  5.4  2.3
# 148  5.9  3.0  5.1  1.8
#
# [149 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,train_size=0.8)
x_test
# Out:
#      5.1  3.5  1.4  0.2
# 73   6.4  2.9  4.3  1.3
# 18   5.1  3.8  1.5  0.3
# 117  7.7  2.6  6.9  2.3
# 78   5.7  2.6  3.5  1.0
# 76   6.7  3.0  5.0  1.7
# 31   5.2  4.1  1.5  0.1
# 64   6.7  3.1  4.4  1.4
# 140  6.9  3.1  5.1  2.3
# 68   5.6  2.5  3.9  1.1
# 82   6.0  2.7  5.1  1.6
# 109  6.5  3.2  5.1  2.0
# 12   4.3  3.0  1.1  0.1
# 36   4.9  3.1  1.5  0.1
# 9    5.4  3.7  1.5  0.2
# 19   5.4  3.4  1.7  0.2
# 56   4.9  2.4  3.3  1.0
# 136  6.4  3.1  5.5  1.8
# 69   5.9  3.2  4.8  1.8
# 55   6.3  3.3  4.7  1.6
# 131  6.4  2.8  5.6  2.2
# 29   4.8  3.1  1.6  0.2
# 123  6.7  3.3  5.7  2.1
# 26   5.2  3.5  1.5  0.2
# 127  6.4  2.8  5.6  2.1
# 128  7.2  3.0  5.8  1.6
# 144  6.7  3.0  5.2  2.3
# 110  6.4  2.7  5.3  1.9
# 101  7.1  3.0  5.9  2.1
# 45   5.1  3.8  1.6  0.2
# 30   5.4  3.4  1.5  0.4

# %%
x2=df.iloc[:,0]
y2=df.iloc[:,1]
x2
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: 5.1, Length: 149, dtype: float64

# %%
x
# Out:
#      5.1  3.5  1.4  0.2
# 0    4.9  3.0  1.4  0.2
# 1    4.7  3.2  1.3  0.2
# 2    4.6  3.1  1.5  0.2
# 3    5.0  3.6  1.4  0.2
# 4    5.4  3.9  1.7  0.4
# ..   ...  ...  ...  ...
# 144  6.7  3.0  5.2  2.3
# 145  6.3  2.5  5.0  1.9
# 146  6.5  3.0  5.2  2.0
# 147  6.2  3.4  5.4  2.3
# 148  5.9  3.0  5.1  1.8
#
# [149 rows x 4 columns]

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
  k=KMeans(n_clusters=i,init="k-means++",max_iter=300)
  k.fit(x)
  wcss.append(k.inertia_)
print(wcss)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,11),wcss)
plt.show()

# %%
kmeans=KMeans(n_clusters=3,max_iter=20,init="k-means++")
kmeans.fit(x)
labels=kmeans.predict(x) 
centroids=kmeans.cluster_centers_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(x.iloc[:,0],x.iloc[:,1],c=labels)
plt.scatter(centroids[:,0],centroids[:,1],color="red",s=200,linewidth=3,marker="*")
plt.show()

# %%
from sklearn.cluster import DBSCAN
db=DBSCAN(eps=0.5,min_samples=5)
db.fit(x)
labels=db.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
print(n_clusters_)
print(n_noise_)
# Out:
# 2
# 17

# %%
plt.scatter(x.iloc[:,0],x.iloc[:,1],c=labels)
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,train_size=0.8)
pca=PCA(n_components=2)
x_train_pca=pca.fit_transform(x_train)
x_test_pca=pca.transform(x_test)
x_test_pca[:,0]
# Out:
# array([ 0.72794443, -2.57018865,  3.80873147, -0.29611216,  1.57189169,
#        -2.62766964,  0.94273011,  1.93530505,  0.05418933,  1.39155034,
#         1.67645977, -3.21353756, -2.66032466, -2.48936655, -2.29482517,
#        -0.74243374,  1.92041148,  1.13061384,  1.11113803,  2.17088419,
#        -2.57522985,  2.29196539, -2.54661045,  2.13543426,  2.40450623,
#         1.95632799,  1.81453083,  2.63140074, -2.5197702 , -2.39566207])

# %%
import pandas as pd
import numpy as np

# create dataframes from the numpy arrays
x_train_df = pd.DataFrame(x_train_pca)
y_train_df = pd.DataFrame(y_train)
x_test_df = pd.DataFrame(x_test_pca)
y_test_df = pd.DataFrame(y_test)

# add the target variable column to the train and test dataframes
x_train_df['target'] = y_train_df
x_test_df['target'] = y_test_df

# concatenate the train and test dataframes vertically
merged_df = pd.concat([x_train_df, x_test_df], axis=0)

# reset the index of the merged dataframe
merged_df = merged_df.reset_index(drop=True)
merged_df
# Out:
#             0         1       target
# 0   -2.289544  0.146748  Iris-setosa
# 1   -2.605407  0.861158  Iris-setosa
# 2    0.673192 -0.324226  Iris-setosa
# 3   -2.774815 -0.184671  Iris-setosa
# 4   -2.391389  0.238280  Iris-setosa
# ..        ...       ...          ...
# 144  1.956328  0.207716          NaN
# 145  1.814531 -0.195418  Iris-setosa
# 146  2.631401  0.358427          NaN
# 147 -2.519770  0.553473          NaN
# 148 -2.395662  0.459202  Iris-setosa
#
# [149 rows x 3 columns]

# %%
merged_df=merged_df.dropna()

# %%
merged_df.isna().sum()
# Out:
# 0         0
# 1         0
# target    0
# dtype: int64

# %%
merged=merged_df.iloc[:,:-1]

# %%
kmeans=KMeans(n_clusters=3,init="k-means++",max_iter=10)
kmeans.fit(merged)
labels=kmeans.predict(merged)
centroids=kmeans.cluster_centers_
plt.scatter(merged.iloc[:,0],merged.iloc[:,1],c=labels)
plt.scatter(centroids[:,0],centroids[:,1],marker="*",linewidth=3,color="red")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import scipy.cluster.hierarchy as shc
dendro=shc.dendrogram(shc.linkage(merged,method="ward")) 
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
ahc=AgglomerativeClustering(affinity="euclidean",n_clusters=2,linkage="ward")
labels=ahc.fit_predict(merged)
plt.scatter(merged.iloc[:,0],merged.iloc[:,1],c=labels) 
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# DECISION TREE

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/weather_forecast.csv")
df
# Out:
#      Outlook Temperature Humidity   Windy Play
# 0      Sunny         Hot     High    Weak   No
# 1      Sunny         Hot     High  Strong   No
# 2   Overcast         Hot     High    Weak  Yes
# 3       Rain        Mild     High    Weak  Yes
# 4       Rain        Cool   Normal    Weak  Yes
# 5       Rain        Cool   Normal  Strong   No
# 6   Overcast        Cool   Normal  Strong  Yes
# 7      Sunny        Mild     High    Weak   No
# 8      Sunny        Cool   Normal    Weak  Yes
# 9       Rain        Mild   Normal    Weak  Yes
# 10     Sunny        Mild   Normal  Strong  Yes
# 11  Overcast        Mild     High  Strong  Yes
# 12  Overcast         Hot   Normal    Weak  Yes
# 13      Rain        Mild     High  Strong   No

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in df.columns:
  df[i]=l.fit_transform(df[i])
df.head()
# Out:
#    Outlook  Temperature  Humidity  Windy  Play
# 0        2            1         0      1     0
# 1        2            1         0      0     0
# 2        0            1         0      1     1
# 3        1            2         0      1     1
# 4        1            0         1      1     1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1,test_size=0.2)
x_test
# Out:
#      5.1  3.5  1.4  0.2
# 145  6.3  2.5  5.0  1.9
# 89   5.5  2.6  4.4  1.2
# 54   5.7  2.8  4.5  1.3
# 77   6.0  2.9  4.5  1.5
# 84   6.0  3.4  4.5  1.6
# 105  4.9  2.5  4.5  1.7
# 91   5.8  2.6  4.0  1.2
# 53   6.5  2.8  4.6  1.5
# 44   4.8  3.0  1.4  0.3
# 59   5.0  2.0  3.5  1.0
# 5    4.6  3.4  1.4  0.3
# 16   5.1  3.5  1.4  0.3
# 93   5.6  2.7  4.2  1.3
# 14   5.7  4.4  1.5  0.4
# 58   5.2  2.7  3.9  1.4
# 33   4.9  3.1  1.5  0.1
# 73   6.4  2.9  4.3  1.3
# 29   4.8  3.1  1.6  0.2
# 66   5.8  2.7  4.1  1.0
# 35   5.5  3.5  1.3  0.2
# 119  6.9  3.2  5.7  2.3
# 144  6.7  3.0  5.2  2.3
# 31   5.2  4.1  1.5  0.1
# 130  7.9  3.8  6.4  2.0
# 111  6.8  3.0  5.5  2.1
# 19   5.4  3.4  1.7  0.2
# 51   6.9  3.1  4.9  1.5
# 48   5.0  3.3  1.4  0.2
# 90   6.1  3.0  4.6  1.4
# 102  6.3  2.9  5.6  1.8

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion="entropy")
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 96.66666666666667

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.93      1.00      0.96        13
#  Iris-virginica       1.00      0.86      0.92         7
#
#        accuracy                           0.97        30
#       macro avg       0.98      0.95      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
from sklearn import tree
text_representation=tree.export_text(dt)
print(text_representation)
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: Iris-setosa
# |--- feature_2 >  2.45
# |   |--- feature_2 <= 4.75
# |   |   |--- class: Iris-versicolor
# |   |--- feature_2 >  4.75
# |   |   |--- feature_3 <= 1.75
# |   |   |   |--- feature_2 <= 4.95
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_2 >  4.95
# |   |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |   |--- class: Iris-virginica
# |   |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |   |--- feature_2 <= 5.45
# |   |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |   |   |--- feature_2 >  5.45
# |   |   |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_3 >  1.75
# |   |   |   |--- feature_2 <= 4.85
# |   |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_2 >  4.85
# |   |   |   |   |--- class: Iris-virginica

# %%
tree.plot_tree(dt)
# Out:
# [Text(0.3, 0.9285714285714286, 'x[2] <= 2.45\nentropy = 1.582\nsamples = 119\nvalue = [39, 37, 43]'),
#  Text(0.2, 0.7857142857142857, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.4, 0.7857142857142857, 'x[2] <= 4.75\nentropy = 0.996\nsamples = 80\nvalue = [0, 37, 43]'),
#  Text(0.3, 0.6428571428571429, 'entropy = 0.0\nsamples = 32\nvalue = [0, 32, 0]'),
#  Text(0.5, 0.6428571428571429, 'x[3] <= 1.75\nentropy = 0.482\nsamples = 48\nvalue = [0, 5, 43]'),
#  Text(0.2, 0.5, 'x[2] <= 4.95\nentropy = 1.0\nsamples = 8\nvalue = [0, 4, 4]'),
#  Text(0.1, 0.35714285714285715, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.3, 0.35714285714285715, 'x[3] <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.2, 0.21428571428571427, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.21428571428571427, 'x[2] <= 5.45\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %%
import graphviz
dot_data=tree.export_graphviz(dt,filled=True)
graph=graphviz.Source(dot_data,format="png")
graph
